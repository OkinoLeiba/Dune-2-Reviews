# %% [markdown]
# ## Dune 2 Reviews

# %%
import pandas as pd, matplotlib.pyplot as plt, numpy as np

# %%
file_path = './dune_2_reviews.csv'
dune_data = pd.read_csv(file_path, delimiter=',', engine='c', encoding='utf-8', encoding_errors='strict', on_bad_lines='error')

# %%
dune_data.head()
# Out:
#                                         Review Title Review Date  \
# 0                    This is what Hollywood needs!\n  2024-02-26
# 1                           Long live the fighters\n  2024-02-26
# 2   Ladies and gentleman.. the PEAK of filmmaking...  2024-02-28
# 3                    WOW! I need Dune Messiah now.\n  2024-02-26
# 4        The Sci-Fi/Fantasy Epic of our Generation\n  2024-02-26
#
#                                       Review Content  User Rating
# 0  This is what Hollywood needs. A great story wi...         10.0
# 1  Phenomenal stuff. I'll probably calm down tomo...          9.0
# 2  This is the kind of movie that is impossible t...         10.0
# 3  If you liked or loved the first one, the same ...         10.0
# 4  Had the pleasure to watch this film in an earl...         10.0

# %%
dune_data.tail()
# Out:
#                                      Review Title Review Date  \
# 1061                       A visual masterpiece\n  2024-03-02
# 1062               Ok. But where is the music?!\n  2024-03-04
# 1063                                        Meh\n  2024-03-01
# 1064                             Dune: Part Two\n  2024-03-05
# 1065   Matrix Revolutions meets Lawrence Arabia\n  2024-03-04
#
#                                          Review Content  User Rating
# 1061  Dune Part 2 is dope to the most extent.Visuall...          8.0
# 1062  First I want to address the majority of "Ones"...          7.0
# 1063  It wasn't a bad movie... but I would rather ha...          6.0
# 1064  Dune: Part Two is a cinematic triumph, a colos...          7.0
# 1065  "I know. Poor Stilgar. Without him, we're lost...          7.0

# %%
dune_data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1066 entries, 0 to 1065
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Review Title    1066 non-null   object
#  1   Review Date     1066 non-null   object
#  2   Review Content  1066 non-null   object
#  3   User Rating     1056 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 33.4+ KB

# %%
dune_data.dtypes
# Out:
# Review Title       object
# Review Date        object
# Review Content     object
# User Rating       float64
# dtype: object

# %%
dune_data.index
# Out:
# RangeIndex(start=0, stop=1066, step=1)

# %%
dune_data.shape
# Out:
# (1066, 4)

# %%
dune_data.columns
# Out:
# Index(['Review Title', 'Review Date', 'Review Content', 'User Rating'], dtype='object')

# %%
dune_data.ndim
# Out:
# 2

# %%
dune_data.isnull().any()
# Out:
# Review Title      False
# Review Date       False
# Review Content    False
# User Rating        True
# dtype: bool

# %%
dune_data.isna().any()
# Out:
# Review Title      False
# Review Date       False
# Review Content    False
# User Rating        True
# dtype: bool

# %%
dune_data.isnull().sum()
# Out:
# Review Title       0
# Review Date        0
# Review Content     0
# User Rating       10
# dtype: int64

# %%
dune_data.isna().sum()
# Out:
# Review Title       0
# Review Date        0
# Review Content     0
# User Rating       10
# dtype: int64

# %%
dune_data[dune_data['User Rating'].isnull()][:5]
# Out:
#                                           Review Title Review Date  \
# 55                                       Snooze fest\n  2024-03-01
# 149                      Epic novel--epic adaptation\n  2024-03-05
# 384        This can't be fiction, you won't fool us!\n  2024-02-28
# 403   Villeneuve's offering solidifies itself as a ...  2024-03-03
# 544                                           Ruin 2\n  2024-03-04
#
#                                         Review Content  User Rating
# 55   If this movie wasn't 3 hours long... if it wer...          NaN
# 149  Since the first part of Dune (2021), Paul (Tim...          NaN
# 384  First of all, let me tell you that I walked ou...          NaN
# 403  Spurred on by revenge as Paul embraces Fremen ...          NaN
# 544  Ruin 2\nI suspect will be no better than Ruin ...          NaN

# %%
dune_data[dune_data['User Rating'].isna()][:5]
# Out:
#                                           Review Title Review Date  \
# 55                                       Snooze fest\n  2024-03-01
# 149                      Epic novel--epic adaptation\n  2024-03-05
# 384        This can't be fiction, you won't fool us!\n  2024-02-28
# 403   Villeneuve's offering solidifies itself as a ...  2024-03-03
# 544                                           Ruin 2\n  2024-03-04
#
#                                         Review Content  User Rating
# 55   If this movie wasn't 3 hours long... if it wer...          NaN
# 149  Since the first part of Dune (2021), Paul (Tim...          NaN
# 384  First of all, let me tell you that I walked ou...          NaN
# 403  Spurred on by revenge as Paul embraces Fremen ...          NaN
# 544  Ruin 2\nI suspect will be no better than Ruin ...          NaN

# %%
dune_data.dropna(axis=0, how='any', inplace=True)

# %%
dune_data.isnull().any()
# Out:
# Review Title      False
# Review Date       False
# Review Content    False
# User Rating       False
# dtype: bool

# %%
dune_data.isna().any()
# Out:
# Review Title      False
# Review Date       False
# Review Content    False
# User Rating       False
# dtype: bool

# %%
dune_data['User Rating'].describe()
# Out:
# count    1056.000000
# mean        8.579545
# std         2.148805
# min         1.000000
# 25%         8.000000
# 50%        10.000000
# 75%        10.000000
# max        10.000000
# Name: User Rating, dtype: float64

# %%
print('Negative User Rating Count: ',  dune_data[dune_data['User Rating'] <= 4.0].count().loc['User Rating'])
# Out:
# Negative User Rating Count:  71

# %%
print('Positive User Rating Count: ',  dune_data[dune_data['User Rating'] >= 6.0].count().loc['User Rating'])
# Out:
# Positive User Rating Count:  953

# %%
dune_data[dune_data['User Rating'] <= 4.0].sample(n=10, random_state=4)
# Out:
#                                            Review Title Review Date  \
# 581                    Too long and unbelievably slow\n  2024-03-05
# 1003   Dune (part one) was fantastic! Dune 2 is just...  2024-02-28
# 952                                          Headache\n  2024-03-02
# 477            Imagine over substance sand over story\n  2024-03-03
# 545                                             Don't\n  2024-03-03
# 87                               Extremely Lackluster\n  2024-03-03
# 461    People have a fight on a sandy planet somewhe...  2024-03-02
# 625                          Slow, uninspiring, borng\n  2024-03-04
# 846                                          Mediocre\n  2024-03-03
# 795                           Try as hard as you like\n  2024-03-02
#
#                                          Review Content  User Rating
# 581   Please tell me that there is not going to be a...          4.0
# 1003  Dune (part one) was fantastic! Dune 2 is just ...          1.0
# ...

# %%
dune_data[dune_data['User Rating'] >= 6.0].sample(n=10, random_state=4)
# Out:
#                                           Review Title Review Date  \
# 693                               Show Them paradise\n  2024-02-29
# 843            Spectacular Sci-fi (watch it on IMAX)\n  2024-03-03
# 949                                        Fantastic\n  2024-03-01
# 80    While things in the first part could come acr...  2024-03-03
# 304                        A whole world to discover\n  2024-03-01
# 178                            More of this, please!\n  2024-03-02
# 283                               Superb film making\n  2024-03-01
# 959                                         Just Wow\n  2024-03-03
# 85                 A Masterclass in Science Fiction.\n  2024-02-26
# 553                              Confusing but great\n  2024-03-01
#
#                                         Review Content  User Rating
# 693  I watched this in Imax, and it was sensationel...         10.0
# 843  Drove 300km to watch this movie on IMAX, it wa...         10.0
# ...

# %%
from wordcloud import WordCloud, STOPWORDS
# from pillow import Image

# brain_mask = np.array(Image.open('C:/Users/okino/OneDrive/Pictures/Black Panther.jpg'))
filter_words = ['film', 'movie', 'this']


filter_text = [[text for text in review_text if review_text not in filter_words] for review_text in dune_data['Review Content']]
# filter_text = filter(lambda word: any(sub in word for sub in filter_words), dune_data['Review Content'])


# combin_filter = filter_words.extend(list(STOPWORDS))
# clean_text = ''.join(word for word in dune_data['Review Content']) #.split()
clean_text = ''.join(word for word in filter_text) 


wordcloud = WordCloud(height=800, width=1200, contour_color='black').generate(clean_text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 14
#       8 filter_text = [[text for text in review_text if review_text not in filter_words] for review_text in dune_data['Review Content']]
#       9 # filter_text = filter(lambda word: any(sub in word for sub in filter_words), dune_data['Review Content'])
#      10
#      11
#      12 # combin_filter = filter_words.extend(list(STOPWORDS))
#      13 # clean_text = ''.join(word for word in dune_data['Review Content']) #.split()
# ---> 14 clean_text = ''.join(word for word in filter_text)
#      17 wordcloud = WordCloud(height=800, width=1200, contour_color='black').generate(clean_text)
#      19 plt.imshow(wordcloud, interpolation='bilinear')
#
# TypeError: sequence item 0: expected str instance, list found

# %%
lists = [5, 7, 22, 97, 54, 62, 77, 23, 73, 61]
filter_words = ['film', 'movies', 'bbkub']
 
final_list = list(filter(lambda x: (x % 2 != 0), lists))
test = [review_text for review_text in clean_text]

# %%
positive_review = dune_data.loc[dune_data['User Rating'] >= 6.0, ['Review Content']]

clean_text = ''.join(word for word in positive_review['Review Content'])

wordcloud = WordCloud(stopwords=list(STOPWORDS), height=800, width=1200, contour_color='black').generate(clean_text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
import re, nltk, string
nltk.download(['stopwords', 'movie_reviews', 'vader_lexicon', 'subjectivity'])
from nltk.sentiment.sentiment_analyzer import SentimentAnalyzer 
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.stem.porter import PorterStemmer
from nltk.corpus import subjectivity
from nltk import tokenize


# subjective_words = [sub for sub in clean_text if sub in [sent for sent in subjectivity.sents(categories='subj')]]

# objective_words = [sub for sub in clean_text if sub in [sent for sent in subjectivity.sents(categories='obj')]]

stop_words = set(nltk.corpus.stopwords.words('english'))

SIA = SentimentIntensityAnalyzer()
SA = SentimentAnalyzer()

table = str.maketrans('', '', string.punctuation)

clean_text = ''.join(word for word in dune_data['Review Content'])

clean = [word.translate(table) for word in re.split(r'\W+', clean_text.lower().strip()) if word not in stop_words]

str_text = " ".join(clean)

# token_words = nltk.tokenize.word_tokenize(str_text, language='english')
# token_words = tokenize.word_tokenize(clean, language='english')

lem_words = porter = PorterStemmer(clean)


_SIA = nltk.sentiment.SentimentIntensityAnalyzer()
_SA = nltk.sentiment.SentimentAnalyzer()


FD = nltk.FreqDist(clean)
print(nltk.FreqDist(clean))
FD.most_common(10)
FD.tabulate(10)

# SIA.polarity_scores(str([word for word in token_words]))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\okino\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\okino\AppData\Roaming\nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\okino\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package subjectivity to
# [nltk_data]     C:\Users\okino\AppData\Roaming\nltk_data...
# [nltk_data]   Package subjectivity is already up-to-date!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 30
#      25 str_text = " ".join(clean)
#      27 # token_words = nltk.tokenize.word_tokenize(str_text, language='english')
# ...

# %%
# from random import randint, randrange
# random_dict = {}
# dataset = []

# # key = []
# # for i in range(10):
# #     key.append(str(randint(0,9)))
# for i in range(3):
#     key = ''.join([str(randint(0,9)) for i in range(10)])
#     random_dict[key] = randrange(10)
#     dataset.append(random_dict)
